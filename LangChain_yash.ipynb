# %%
import os
import zipfile
import pandas as pd
import yaml
import google.generativeai as genai

# %%
os.environ["GEMINI_API_KEY"] = ""
genai.configure(api_key=os.environ["GEMINI_API_KEY"])

# %%
def extract_zip(file_path, extract_to):
    with zipfile.ZipFile(file_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)

# %%
def read_java_files(directory):
    java_files = {}
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.java'):
                fname = file.split('.')[0]
                with open(os.path.join(root, file), 'r') as f:
                    code = (file, f.read())
                    java_files[fname] = code
    return java_files

# %%
def call_gemini_api(prompt):
    try:
        model = genai.GenerativeModel('gemini-pro')
        response = model.generate_content(prompt)
        return response.text
    except Exception as e:
        return ""  # Or provide a default value for error cases

# %%
def generate_excel_report(results, output_file):
    df = pd.DataFrame(results)
    df.to_excel(output_file, index=False)

# %%
def main(zip_file_path, extract_to, prompts, df):
    assgn_list = os.listdir(zip_file_path)
    count = 1
    for eachfile in assgn_list:
        # print(eachfile)
        row = []
        rollno = eachfile.split('.')[0]
        row.append(rollno)
        extract_zip('Mini_eval1_Forenoon/'+eachfile, extract_to)
        java_files_list = {}
        java_files_list = read_java_files(extract_to + '/' + rollno + '/')
        # print(java_files_list)
        print(str(count)+" "+str(rollno))
        for key in prompts:
            code = java_files_list.get(key)
            print(key, end=" ")
            # print(code,end="->")
            prompt = prompts.get(key)
            for eachPrompt in prompt:
                response = ''
                while response=='':
                    prompt_template = f"Java code:\n{code}\n question:{eachPrompt} \n give response in one line"
                    # print(prompt_template)
                    response = call_gemini_api(prompt_template)
                    if response!='':
                        # print(response)
                        row.append(response)
        count = count + 1
        print()
        # print(rollno)
        # print(len(row))
        # print(row)
        df.loc[len(df)] = row

    
    # generate_excel_report(results, output_file)

# %%
zip_file_path = 'Mini_eval1_Forenoon'  # Ensure the correct path to your zip file
extract_to = 'extracted_files'
yaml_file_path = 'minieval1.yaml'
output_file = 'MINI_EVAL1_FN_F15.xlsx'
prompts = {}
col = ['RollNo']
with open(yaml_file_path, 'r') as f:
    yaml_content = yaml.safe_load(f)
    for key in yaml_content:
        prompts[key] = yaml_content[key]
        for subque in prompts[key]:
            col.append(key + ':' +subque)

df = pd.DataFrame(columns=col)
# print(prompts)
main(zip_file_path,extract_to, prompts, df)
generate_excel_report(df, output_file)
# Out:
# 1 B220019CS
# Q1 Q2 Q3
# 2 B220024CS
# Q1 Q2 Q3
# 3 B220027CS
# Q1 Q2 Q3
# 4 B220042CS
# Q1 Q2 Q3
# 5 B220087CS
# Q1 Q2 Q3
# 6 B220118CS
# Q1 Q2 Q3
# 7 B220138CS
# Q1 Q2 Q3
# 8 B220160CS
# Q1 Q2 Q3
# 9 B220169CS
# Q1 Q2 Q3
# 10 B220185CS
# Q1 Q2 Q3
# 11 B220279CS
# Q1 Q2 Q3
# 12 B220331CS
# Q1 Q2 Q3
# 13 B220349CS
# Q1 Q2 Q3
# 14 B220397CS
# Q1 Q2 Q3
# 15 B220498CS
# Q1 Q2 Q3
# 16 B220516CS
# Q1 Q2 Q3
# 17 B220571CS
# Q1 Q2 Q3
# 18 B220937CS
# Q1 Q2 Q3
# 19 B221324CS
# Q1 Q2 Q3

# %%
display(df)
# Out:
#        RollNo Q1:what is the output when the input is "Hello world"  \
# 0   B220019CS                                        dlrow olleH
# 1   B220024CS                                        dlrow olleH
# 2   B220027CS                                        dlrow olleH
# 3   B220042CS                                        dlrow olleH
# 4   B220087CS                              Output: "dlrow olleH"
# 5   B220118CS                     reversed String is:dlrow olleH
# 6   B220138CS                        The output is "dlrow olleH"
# 7   B220160CS                                        dlrow olleH
# 8   B220169CS                  The output will be: "dlrow olleH"
# 9   B220185CS                                      "dlrow olleH"
# 10  B220279CS                                        dlrow olleH
# 11  B220331CS                  The output will be: "dlrow olleH"
# 12  B220349CS                                        dlrow olleH
# 13  B220397CS                                        dlrow olleH
# 14  B220498CS                                        dlrow olleH
# 15  B220516CS                                        dlrow olleH
# 16  B220571CS                                      "dlrow olleH"
# 17  B220937CS                                        dlrow olleH
# 18  B221324CS                                       dlr ow olleH
#
#    Q1:Is recursion used? If not, write the logic used to reverse the string.  \
# 0   Yes, recursion is used in this code to reverse...
# 1       Yes, recursion is used to reverse the string.
# 2            Recursion is used to reverse the string.
# 3       Yes, recursion is used to reverse the string.
# 4                             Yes, recursion is used.
# 5       Yes, recursion is used to reverse the string.
# 6                             Yes, recursion is used.
# 7        Yes, recursion is used in the provided code.
# 8            Recursion is used to reverse the string.
# 9             Recursion is used in the provided code.
# 10           Recursion is used to reverse the string.
# 11          Yes, recursion is used in this Java code.
# 12      Yes, recursion is used to reverse the string.
# 13  Yes, recursion is employed in this code to rev...
# 14  Yes, the logic is using recursion to reverse t...
# 15  Recursion is used in the given Java code to re...
# 16      Yes, recursion is used to reverse the string.
# 17  Recursion is used to reverse the string by cal...
# 18               Yes, recursion is used in this code.
#
#    Q1:Write any syntax error if present. otherwise write "NO ERROR"  \
# 0                                            NO ERROR
# 1                                            NO ERROR
# 2                                            NO ERROR
# 3                                            NO ERROR
# 4                                            NO ERROR
# 5                                            NO ERROR
# 6                                            NO ERROR
# 7                                            NO ERROR
# 8                                            NO ERROR
# 9                                            NO ERROR
# 10                                           NO ERROR
# 11                                           NO ERROR
# 12                                           NO ERROR
# 13                                           NO ERROR
# 14                                           NO ERROR
# 15                                           NO ERROR
# 16                                           NO ERROR
# 17                                           NO ERROR
# 18                                           NO ERROR
#
#           Q2:List all class names in present in code.  \
# 0                                 Q2, Manager, Person
# 1   Member, Student, FacultyMember, LibrarySystem, Q2
# 2           Student, FacultyMember, LibrarySystem, Q2
# 3                 Person, LibraryManagementSystem, Q2
# 4                          Q2,library,student,faculty
# 5                                                 N/A
# 6               Student, FacultyMember, LibrarySystem
# 7                           library, student, faculty
# 8                       Student, Faculty, Library, Q2
# 9   Q2, Members, Student, FacultyMember, LibraryMa...
# 10                        Student, Facultymembers, Q2
# 11         Q2, Student, FacultyMemeber, LibrarySystem
# 12  Q2, Student, FacultyMember, Person, LibrarySystem
# 13          Student, FacultyMember, LibrarySystem, Q2
# 14          Q2, Student, FacultyMember, LibrarySystem
# 15                           Person, Student, Faculty
# 16  Q2, Student, FacultyMember, Member, LibrarySystem
# 17  Q2, Student, Member, FacultyMember, LibrarySystem
# 18          Q2, LibrarySystem, Student, FacultyMember
#
#                 Q2:Is Student class present in code?  \
# 0                                                 No
# 1                                                Yes
# 2     Yes, the Student class is present in the code.
# 3                                                 No
# 4   Yes, Student class is present in the given code.
# 5                                                 No
# 6                                                Yes
# 7         Yes, Student class is present in the code.
# 8                                                yes
# 9         Yes, Student class is present in the code.
# 10        Yes, Student class is present in the code.
# 11                                               Yes
# 12        Yes, Student class is present in the code.
# 13                                               Yes
# 14        Yes, Student class is present in the code.
# 15                                                No
# 16        Yes, Student class is present in the code.
# 17                                               Yes
# 18        Yes, Student class is present in the code.
#
#            Q2:Is FacultyMember class present in code?  \
# 0                                                  No
# 1    Yes, FacultyMember class is present in the code.
# 2    Yes, FacultyMember class is present in the code.
# 3   No, there is no FacultyMember class present in...
# 4   No, FacultyMember class is not present in the ...
# 5     FacultyMember class is not present in the code.
# 6   Yes, FacultyMember class is present in the pro...
# 7   No, FacultyMember class is not present in the ...
# 8                                                  No
# 9    Yes, FacultyMember class is present in the code.
# 10  Yes, FacultyMembers class is present in the code.
# 11   Yes, FacultyMember class is present in the code.
# 12   Yes, FacultyMember class is present in the code.
# 13                                                No.
# 14   Yes, FacultyMember class is present in the code.
# 15                                                 No
# 16         Yes,  FacultyMember class present in code.
# 17   Yes, FacultyMember class is present in the code.
# 18   Yes, FacultyMember class is present in the code.
#
#            Q2:Is LibrarySystem class present in code?  \
# 0                                                  No
# 1                                                 Yes
# 2    Yes, LibrarySystem class is present in the code.
# 3                                                  No
# 4                                                  No
# 5                                                  No
# 6          Yes, LibrarySystem is present in the code.
# 7                                                  No
# 8   No, LibrarySystem class is not present in the ...
# 9                                                  No
# 10  No, LibrarySystem class is not present in the ...
# 11                                 Yes, it is present
# 12   Yes, LibrarySystem class is present in the code.
# 13   Yes, LibrarySystem class is present in the code.
# 14   Yes, LibrarySystem class is present in the code.
# 15                                                 No
# 16   Yes, LibrarySystem class is present in the code.
# 17   Yes, LibrarySystem class is present in the code.
# 18                                                Yes
#
#    Q2:List methods present in Student class, return None if class not found.  \
# 0                                                None
# 1                   calculateFine(), displayDetails()
# 2                       calculateFine, displayDetails
# 3                                                None
# 4   student(String name,int days), getName(), getD...
# 5                                                None
# 6     calculateFine(), displayDetails(), getoverdue()
# 7                                student(String, int)
# 8                       calculateFine, displayDetails
# 9                                             Student
# 10       addstudent, calculatefine, listsort, display
# 11                  calculateFine(), displayDetails()
# 12               calculateFine() and displayDetails()
# 13                                               None
# 14                      calculateFine, displayDetails
# 15                                               None
# 16                      calculateFine, displayDetails
# 17                      calculateFine, displayDetails
# 18                         calculateFine(), display()
#
#    Q2:List methods present in FacultyMember class, return None if class not found.  \
# 0                                                None
# 1                    calculateFine(),displayDetails()
# 2                       calculateFine, displayDetails
# 3                                                None
# 4                                                None
# 5                                                None
# 6     calculateFine(), displayDetails(), getoverdue()
# 7                                                None
# 8               calculateFineFac, displayDetailsofFac
# 9                                                None
# 10  The FacultyMember class does not contain any l...
# 11                      calculateFine, displayDetails
# 12                                               None
# 13                                               None
# 14                  calculateFine(), displayDetails()
# 15                                               None
# 16                      calculateFine, displayDetails
# 17                  calculateFine(), displayDetails()
# 18                             calculateFine, display
#
#     ... Q2:Tell me the logic behind calculateFine() in Student.  \
# 0   ...  The calculateFine() method in Student class ca...
# 1   ...  The calculateFine() method in the Student clas...
# 2   ...  The logic behind calculateFine() in Student is...
# 3   ...  It calculates the fine amount based on the num...
# 4   ...  Java code does not contain calculateFine() met...
# 5   ...  This method calculates the fine of a Student b...
# 6   ...  The calculateFine() method calculates the fine...
# 7   ...  The calculateFine() method in the Student clas...
# 8   ...  The calculateFine() method in Student calculat...
# 9   ...  The calculateFine() method in the Student clas...
# 10  ...  The calculateFine() method in Student class ca...
# 11  ...  The `calculateFine()` method in the `Student` ...
# 12  ...  The logic behind calculateFine() in Student cl...
# 13  ...  The calculateFine() method in Student calculat...
# 14  ...  The calculateFine() method in the Student clas...
# 15  ...  Returns the fine amount for a student, which i...
# 16  ...  Calculates a fine of 50 rupees per overdue day...
# 17  ...  The calculateFine() method in the Student clas...
# 18  ...  calculateFine() method calculates the total fi...
#
#    Q2:Tell me the logic behind calculateFine() in FacultyMember.  \
# 0   Person class calculates the fine based on the ...
# 1   It calculates the fine for a faculty member by...
# 2   It returns the overdue fine for the faculty me...
# 3   There is no calculateFine() method in FacultyM...
# 4   The logic behind calculateFine() in FacultyMem...
# 5   Calculates the total fine based on the specifi...
# 6   The calculateFine() method in FacultyMember ca...
# 7   The calculateFine() method in FacultyMember cl...
# 8   The calculateFine() method in FacultyMember ca...
# 9   The calculateFine() method is not defined in t...
# 10   This method is not defined in the provided code.
# 11  The calculateFine() method in FacultyMember ca...
# 12  The calculateFine() method in FacultyMember ca...
# 13  The logic behind calculateFine() in FacultyMem...
# 14  It calculates the fine for a faculty member by...
# 15  The calculateFine() method calculates the fine...
# 16  The calculateFine() method in FacultyMember ca...
# 17  Calculates the fine for a faculty member based...
# 18  The calculateFine() method in FacultyMember ca...
#
#           Q3:Does the program have a StopLight class?  \
# 0                                                 Yes
# 1                    Yes, there is a StopLight class.
# 2                                                 Yes
# 3             Yes, the program has a StopLight class.
# 4                                                 Yes
# 5   The provided code does not have a StopLight cl...
# 6                                                  No
# 7                                                  No
# 8                                                  No
# 9                                       Yes, it does.
# 10          The code does not have a StopLight class.
# 11            No, it has a StopLightController class.
# 12            Yes, the program has a StopLight class.
# 13                                       Yes, it does
# 14            Yes, the program has a StopLight class.
# 15            Yes, the program has a StopLight class.
# 16                                                 No
# 17                                      Yes, it does.
# 18       Yes, the Java program has a StopLight class.
#
#    Q3:Does the class StopLight have an instance variable called state?  \
# 0   Yes, the class StopLight has an instance varia...
# 1   Yes, the class StopLight has an instance varia...
# 2   Yes, the class StopLight has an instance varia...
# 3   No, the class StopLight has an instance variab...
# 4                                                 Yes
# 5   The code does not provide the class StopLight,...
# 6                                                  No
# 7                                                 Yes
# 8   Yes, the StopLight class has an instance varia...
# 9   Yes, the class StopLight has an instance varia...
# 10                                                Yes
# 11  Yes, the class StopLight has an instance varia...
# 12  Yes, the class StopLight has an instance varia...
# 13                                                Yes
# 14  Yes, the class `StopLight` has an instance var...
# 15  Yes, the class StopLight has an instance varia...
# 16  Yes, StopLightController has an instance varia...
# 17                                                Yes
# 18  Yes, the class StopLight has an instance varia...
#
#    Q3:Does the StopLightController class contain the main method?  \
# 0                                                 No.
# 1   Yes, the StopLightController class contains th...
# 2   Yes, the StopLightController class contains th...
# 3   Yes, the StopLightController class contains th...
# 4   Yes, the StopLightController class does contai...
# 5                                                  No
# 6                                                  No
# 7                                                  No
# 8                                                  No
# 9   Yes, the StopLightController class contains th...
# 10  The provided code does not contain the StopLig...
# 11  No, the StopLightController class does not con...
# 12  Yes, the StopLightController class contains th...
# 13                                      Yes, it does.
# 14         No, the class Q3 contains the main method.
# 15                                                No.
# 16  No, the StopLightController class does not con...
# 17  Yes, the StopLightController class contains th...
# 18  Yes, the StopLightController class contains th...
#
#    Q3:Does the state of the stoplight change when the user presses key 'N'?  \
# 0   Yes, the state of the stoplight changes to the...
# 1   Yes, the state changes when the user presses 'N'.
# 2   Yes, the state of the stoplight changes to the...
# 3   Yes, the state of the stoplight changes to the...
# 4   Yes, the state of the stoplight changes to the...
# 5                                                  No
# 6                                                  No
# 7   Yes, the state of the stoplight changes to the...
# 8   Yes, the state of the stoplight changes when t...
# 9   Yes, the state of the stoplight changes to the...
# 10  Yes, the state of the stoplight changes to GRE...
# 11  Yes, the state of the stoplight changes when t...
# 12  Yes, the state of the stoplight changes when t...
# 13  Yes, the state of the stoplight changes when t...
# 14  Yes, the state of the stoplight changes when t...
# 15  Yes, the state of the stoplight changes when t...
# 16  Yes, the state of the stoplight changes when t...
# 17  Yes, the state of the stoplight changes when t...
# 18  Yes, the state of the stoplight changes to the...
#
#    Q3:When the present state is Yellow does it change to Red when the user presses key 'N'?  \
# 0                                       Yes, it does.
# 1   Yes, when the present state is Yellow (state =...
# 2                                       Yes, it does.
# 3   Yes, when the present state is Yellow it chang...
# 4                                                 Yes
# 5                                                 No.
# 6                                                  No
# 7                                                 Yes
# 8   Yes, when the present state is Yellow, it chan...
# 9                                       Yes, it does.
# 10  Yes, it changes to Red when the user presses k...
# 11  Yes, when the present state is Yellow, it chan...
# 12                                    No, it doesn't.
# 13  Yes, when the present state is Yellow, it chan...
# 14  Yes, when the present state is Yellow, it chan...
# 15  Yes, when the present state is Yellow, it chan...
# 16                                                Yes
# 17                            Yes, it changes to Red.
# 18  Yes, when the present state is Yellow, it chan...
#
#    Q3:When the present state is Green does it change to Yellow when the user presses key 'N'?  \
# 0   Yes, the state changes to Yellow when the pres...
# 1   Yes, the state changes from Green to Yellow wh...
# 2   Yes, when the present state is Green and the u...
# 3   Yes, when the present state is Green, it chang...
# 4   Yes, it changes to Yellow when the user presse...
# 5                                                  No
# 6                                                  No
# 7                                       Yes, it does.
# 8                                                 Yes
# 9                                        Yes, it does
# 10                                                 No
# 11  Yes, it changes to Yellow when the user presse...
# 12  Yes, when the present state is Green, it chang...
# 13  Yes, the state changes to Yellow when the user...
# 14  Yes, the state changes to Yellow when the user...
# 15  Yes, it changes to Yellow when the user presse...
# 16  Yes, when the present state is Green, it chang...
# 17                                      Yes, it does.
# 18  Yes, when the present state is Green it change...
#
#    Q3:When the present state is Red does it change to Green when the user presses key 'N'?  \
# 0                          No, it advances to Yellow.
# 1                                                  No
# 2                           No, it changes to Yellow.
# 3   Yes, when the present state is Red, it changes...
# 4   Yes, when the present state is Red, it changes...
# 5                                                  No
# 6                                                  No
# 7                           No, it changes to Yellow.
# 8                                                 Yes
# 9   No, it does not change to Green when user pres...
# 10  Yes, when the present state is Red, it changes...
# 11  Yes, the state changes to Green when the prese...
# 12                          No, it changes to Yellow.
# 13  Yes, when the present state is Red, it changes...
# 14                    No, it doesn't change to Green.
# 15  Yes, when the present state is Red, it changes...
# 16  Yes, when the present state is Red, it changes...
# 17                                      Yes, it does.
# 18  Yes, it changes to Green when the user presses...
#
#    Q3:Does the StopLight class have any printf statement? If yes respond 'StopLight class has print statement'.
# 0             StopLight class has no print statement.
# 1            StopLight class has no printf statement.
# 2                 StopLight class has print statement
# 3              StopLight class has no print statement
# 4                 StopLight class has print statement
# 5                 StopLight class has print statement
# 6                 StopLight class has print statement
# 7            StopLight class has no printf statement.
# 8             StopLight class has no printf statement
# 9              StopLight class has no print statement
# 10                StopLight class has print statement
# 11            StopLight class has no printf statement
# 12           StopLight class has no printf statement.
# 13           StopLight class has no printf statement.
# 14           StopLight class has no printf statement.
# 15                StopLight class has print statement
# 16               StopLight class has print statement.
# 17             StopLight class has no print statement
# 18            StopLight class has no print statement.
#
# [19 rows x 25 columns]
